# %%
import pandas as pd

# %%
df_historical = pd.read_csv('C:\Users\iulia\desktop\Final_Project\data\raw\historical_worldnews.csv')
df_realtime = pd.read_csv('C:\Users\iulia\desktop\Final_Project\data\raw\realtime_worldnews.csv')
